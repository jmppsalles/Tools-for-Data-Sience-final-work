# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **João Marcos Salles**
#
# Project Manager

# %% [markdown]
# *I'm interested in Data Science and Data Analysis because it is the most interesting job area currently and in the foreseeable future, and I want to ride this wave for all its worth.*

# %% [markdown]
# ### The following cell just shows how to convert fahrenheit to celcius

# %%
def fahrenheit_to_celsius(F):
  C = (F - 32) * (5/9)
  return C

fahrenheit = 100
celsius = fahrenheit_to_celsius(fahrenheit)

print("Temperature in Fahrenheit:", fahrenheit)
print("Temperature in Celsius:", celsius)
# Out:
# Temperature in Fahrenheit: 100
# Temperature in Celsius: 37.77777777777778

# %% [markdown]
# ---
# 1. Bulleted list:
#     * My first item of the bullteted list
#     * My second item of the bulleted list
#
# #
# #
#
# 2. Numbered list:
#     1. Item nº 1 of Numbered List
#     2. Item nº 2 of numbered List
#
#
#
# [3. Link to Google: ](https://www.google.com)
